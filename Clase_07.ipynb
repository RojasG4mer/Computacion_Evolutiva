# %% [markdown]
# - Agregar probabilidad de cruza
# - Ver que semilla hace para cambiar los datos, una forma es con el reloj.
# - Agregar transformacion para mas variables con el algoritmo genetico, al menos 2, en intervalos diferentes
# - Usar funciones de De Jong
# - Usar transformacion gray en lugar de binario, hacer de binario a gray, de gray a binario y de gray a decimal
# -
