# %% [markdown]
# - Si salen aptitudes negativas no se puede optimizar porque se eliminan los totales.

# %% [markdown]
# # Principios de Diseño de la Función Objetivo
#
# - La función objetivo debe reflejar las medidas relevantes a ser optimizadas.
# - La función objetivo debe exhibir regularidad sobre el espacio definido por la representación seleccionada.
# - La función objetivo debe abastecer de información suficiente para conducir la presión de selección del algoritmo evolutivo.

# %% [markdown]
# # Tarea
# - Investigar selection pression
